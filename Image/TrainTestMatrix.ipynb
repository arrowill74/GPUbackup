# %% [markdown]
# # Genre 轉為 Matrix

# %%
# Basic import
import os
import sys
import json
import shutil
import pandas as pd
import numpy as np

# %%
# Helper function
def writeProgress(msg, count, total):
    sys.stdout.write(msg + "{:.2%}\r".format(count/total))
    sys.stdout.flush()
    
def newPath(path):
    if not os.path.isdir(path):
        os.mkdir(path)

def read_json(src_path):
    with open(src_path, 'r') as json_file:
        data = json.load(json_file)
    return data

def write_json(data,dst_path):
    with open(dst_path, 'w') as outfile:
        json.dump(data, outfile)

# %%
# 讀取固定的類別順序
genres = read_json('../orderdListGenres.json')
print(len(genres), genres)
# Out:
# 20 ['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Music', 'Mystery', 'Romance', 'Sci-Fi', 'Sport', 'Thriller', 'War', 'Western']

# %%
# 讀取電影所屬的分類
genresMat = read_json('../genresMat.json')
len(genresMat)
# Out:
# 166

# %% [markdown]
# # Extract Poster

# %% [markdown]
# ## Copy Poster to Poster/

# %%
PATH = '../Profiles/'
POSTER = './Poster/'
newPath(POSTER)

# %%
li = []
for folder in os.listdir(PATH):
    print(folder)
    src = PATH + folder + '/poster.jpeg'
    name = folder + '.jpg'
    dst = POSTER + name
    shutil.copy(src, dst)
    li.append([src] + [name] + genresMat[folder])
# Out:
# artofracingmovie
# hotelmumbaifilm
# lighthousemovie
# littlewoodsfilm
# fightingwmyfam
# playingwithfire
# rocketmanmovie
# catsmovie
# xmenmovies
# scarystoriesmovie
# toystory
# brittanyrunsmov
# pomsmovie
# brightburnmovie
# shaftmovie
# theprodigymovie
# petsematarymovie
# missinglinkfilm
# midwaymovie
# adastramovie
# beachbummovie
# peanutbutterfalcon
# arcticmovie
# disneymaleficent
# wrinklestheclown
# wonderparkmovie
# onthebasisofsex
# angelhasfallen
# everybodyknowsmovie
# thehighwaymen
# playmobilthemovie
# alitamovie
# harrietfilm
# blackchristmas
# overcomermovie
# theupsidefilm
# littlethemovie
# disneyaladdin
# lastblackmansf
# lordsofchaosmovie
# countdown
# thehummingbirdprojectfilm
# booksmart
# blindedbythelightmovie
# thenightingalefilm
# escaperoom
# aftermathmovie
# hustlemovie
# abominablemovie
# serenityfilm
# yesterdaymovie
# zombieland
# queenandslim
# lalloronamovie
# dontletgomovie
# motherlessbklyn
# lionking
# amazinggracemov
# jojorabbitmovie
# hellboymovie
# longshotmovie
# thefarewell
# taosdfilm
# yardiefilm
# themustangfilm
# downtonabbey_official
# glassmovie
# meninblack
# shazammovie
# jumanjimovie
# aftermovie
# readyornotfilm
# terminator
# itmovieofficial
# secretlifeofpets
# detectivepikachumovie
# jayandsilentbob
# lastchristmasthemovie
# onceinhollywood
# abeautifuldaymovie
# thedeaddontdie
# piercingmovie
# captivestatemovie
# wavesmovie
# bernadettefilm
# angrybirdsmovie
# richardjewellfilm
# happydeathdaymovie
# uncutgems
# darkwatersmovie
# childsplaymovie
# theirishmanfilm
# goldfinchmovie
# latenightmovie
# johnwickmovie
# hustlersmovie
# arcticdogsmovie
# rambomovie
# doctorsleepmovie
# thesunisalsoastar
# bombshellmovie
# triplefrontier
# justmercyfilm
# uglydolls
# breakthroughmovie
# highstrungmovie
# 21bridgesmovie
# ahiddenlifefilm
# theintrudermovie
# dumbo
# httydragon
# captainmarvelofficial
# halathemovie
# whatmenwant
# godzillamovie
# dolemiteismyname
# lucyintheskyfilm
# charliesangels
# thebestofenemies
# tolkienmovie
# fastandfuriousmovie
# isntitromantic
# geminimanmovie
# midsommarmovie
# fordvferrari
# littlewomenmovie
# brianbanksmovie
# underthesilverlake
# clarathefilm
# hersmellmovie
# freaksthefilm
# annamovie
# marriagestory
# honeyboymovie
# blackandbluemovie
# spiesindisguise
# meettheaddams
# coldpursuitmovie
# judythefilm
# fivefeetapartfilm
# mamovie2019
# thekitchenmovie
# jokermovie
# stubermovie
# gretafilm
# theaeronautsmov
# doramovie
# annabellemovie
# stormboymovie
# starwars
# gloriabellmovie
# currentwarmovie
# disneyfrozen
# highlifemovie
# missbalamovie
# usmovie
# goodliarmovie
# 47metersdown
# thelegomovie
# avengers
# knivesout
# spidermanmovie
# teenspiritmov
# apollo11movie
# adogsjourneymovie
# goodboysmovie

# %% [markdown]
# ## Filename to genre matrix dataframe

# %%
df = pd.DataFrame(li, columns = ['from', 'filename'] + genres).sort_values(by='filename')
df
# Out:
#                                            from                filename  \
# 106      ../Profiles/21bridgesmovie/poster.jpeg      21bridgesmovie.jpg
# 157        ../Profiles/47metersdown/poster.jpeg        47metersdown.jpg
# 79   ../Profiles/abeautifuldaymovie/poster.jpeg  abeautifuldaymovie.jpg
# 48      ../Profiles/abominablemovie/poster.jpeg     abominablemovie.jpg
# 19         ../Profiles/adastramovie/poster.jpeg        adastramovie.jpg
# ..                                          ...                     ...
# 24     ../Profiles/wrinklestheclown/poster.jpeg    wrinklestheclown.jpg
# 8            ../Profiles/xmenmovies/poster.jpeg          xmenmovies.jpg
# 63           ../Profiles/yardiefilm/poster.jpeg          yardiefilm.jpg
# 50       ../Profiles/yesterdaymovie/poster.jpeg      yesterdaymovie.jpg
# 51           ../Profiles/zombieland/poster.jpeg          zombieland.jpg
#
#      Action  Adventure  Animation  Biography  Comedy  Crime  Documentary  \
# 106       1          0          0          0       0      1            0
# 157       0          1          0          0       0      0            0
# 79        0          0          0          1       0      0            0
# 48        0          1          1          0       1      0            0
# 19        0          1          0          0       0      0            0
# ..      ...        ...        ...        ...     ...    ...          ...
# 24        0          0          0          0       1      0            1
# 8         1          1          0          0       0      0            0
# 63        0          0          0          0       0      1            0
# 50        0          0          0          0       1      0            0
# 51        1          0          0          0       1      0            0
#
#      Drama  ...  History  Horror  Music  Mystery  Romance  Sci-Fi  Sport  \
# 106      1  ...        0       0      0        0        0       0      0
# 157      1  ...        0       1      0        0        0       0      0
# 79       1  ...        0       0      0        0        0       0      0
# 48       0  ...        0       0      0        0        0       0      0
# 19       1  ...        0       0      0        1        0       0      0
# ..     ...  ...      ...     ...    ...      ...      ...     ...    ...
# 24       0  ...        0       1      0        0        0       0      0
# 8        0  ...        0       0      0        0        0       1      0
# 63       1  ...        0       0      0        0        0       0      0
# 50       0  ...        0       0      1        0        0       0      0
# 51       0  ...        0       1      0        0        0       0      0
#
#      Thriller  War  Western
# 106         0    0        0
# 157         0    0        0
# 79          0    0        0
# 48          0    0        0
# 19          0    0        0
# ..        ...  ...      ...
# 24          0    0        0
# 8           0    0        0
# 63          0    0        0
# 50          0    0        0
# 51          0    0        0
#
# [166 rows x 22 columns]

# %%
df.to_csv('./poster2genreMat.csv', index = 0)

# %% [markdown]
# # Extract all img and cover in posts

# %% [markdown]
# ## Copy from Post/ to IGimg/

# %%
PATH = '../Posts/'
IG_IMG = './IGimg/'
newPath(IG_IMG)

# %%
li = []
for folder in os.listdir(PATH):
    print(folder)
    postList = os.listdir(PATH + folder) # all posts for each account
    length = len(postList)
    i = 0
    for postID in postList:
        postPath = PATH + folder + '/' + postID + '/'
        post = read_json(postPath + 'post.json')
        writeProgress('Progress:', i, length)
        
        if post['media_type'] in [1, 8]:
            for file in os.listdir(postPath):
                if 'img' in file:
                    src = postPath + file
                    dst = IG_IMG + '/'
                    count = len(os.listdir(dst))
                    name = folder + '_' + str(count) + '.jpg'
                    shutil.copy(src, dst + name)
                    li.append([src] + [name] + genresMat[folder])
                    
        elif post['media_type'] == 2:
            for file in os.listdir(postPath):
                if 'img' in file:
                    src = postPath + file
                    dst = IG_IMG + '/'
                    count = len(os.listdir(dst))
                    name = folder + '_' + str(count) + '.jpg'
                    shutil.copy(src, dst + name)
                    li.append([src] + [name] + genresMat[folder])
                    
        else:
            print('Unknown media_type', post['media_type'])
            
        i += 1
# Out:
# artofracingmovie
# hotelmumbaifilm
# lighthousemovie
# littlewoodsfilm
# fightingwmyfam%
# playingwithfire
# rocketmanmovie%
# catsmovie98.81%
# xmenmovies7.62%
# scarystoriesmovie
# toystory:98.46%
# brittanyrunsmov
# pomsmovie97.62%
# brightburnmovie
# shaftmovie8.77%
# theprodigymovie
# petsematarymovie
# missinglinkfilm
# midwaymovie.03%
# adastramovie53%
# beachbummovie9%
# peanutbutterfalcon
# arcticmovie.45%
# disneymaleficent
# wrinklestheclown
# wonderparkmovie
# onthebasisofsex
# angelhasfallen%
# everybodyknowsmovie
# thehighwaymen8%
# playmobilthemovie
# alitamovie8.04%
# harrietfilm.44%
# blackchristmas%
# overcomermovie%
# theupsidefilm0%
# littlethemovie%
# disneyaladdin1%
# lastblackmansf%
# lordsofchaosmovie
# countdown97.96%
# thehummingbirdprojectfilm
# booksmart97.06%
# blindedbythelightmovie
# thenightingalefilm
# escaperoom5.00%
# aftermathmovie%
# hustlemovie.96%
# abominablemovie
# serenityfilm24%
# yesterdaymovie%
# zombieland8.77%
# queenandslim32%
# lalloronamovie%
# dontletgomovie%
# motherlessbklyn
# lionking:98.75%
# amazinggracemov
# jojorabbitmovie
# hellboymovie25%
# longshotmovie1%
# thefarewell.36%
# taosdfilm96.77%
# yardiefilm7.50%
# themustangfilm%
# downtonabbey_official
# glassmovie9.90%
# meninblack8.96%
# shazammovie.13%
# jumanjimovie10%
# aftermovie9.71%
# readyornotfilm%
# terminator8.68%
# itmovieofficial
# secretlifeofpets
# detectivepikachumovie
# jayandsilentbob
# lastchristmasthemovie
# onceinhollywood
# abeautifuldaymovie
# thedeaddontdie%
# piercingmovie2%
# captivestatemovie
# wavesmovie8.53%
# bernadettefilm%
# angrybirdsmovie
# richardjewellfilm
# happydeathdaymovie
# uncutgems99.37%
# darkwatersmovie
# childsplaymovie
# theirishmanfilm
# goldfinchmovie%
# latenightmovie%
# johnwickmovie8%
# hustlersmovie6%
# arcticdogsmovie
# rambomovie7.14%
# doctorsleepmovie
# thesunisalsoastar
# bombshellmovie%
# triplefrontier%
# justmercyfilm3%
# uglydolls99.37%
# breakthroughmovie
# highstrungmovie
# 21bridgesmovie%
# ahiddenlifefilm
# theintrudermovie
# dumboess:98.78%
# httydragon8.72%
# captainmarvelofficial
# halathemovie44%
# whatmenwant.44%
# godzillamovie6%
# dolemiteismyname
# lucyintheskyfilm
# charliesangels%
# thebestofenemies
# tolkienmovie39%
# fastandfuriousmovie
# isntitromantic%
# geminimanmovie%
# midsommarmovie%
# fordvferrari56%
# littlewomenmovie
# brianbanksmovie
# underthesilverlake
# clarathefilm75%
# hersmellmovie4%
# freaksthefilm9%
# annamovie99.27%
# marriagestory6%
# honeyboymovie4%
# blackandbluemovie
# spiesindisguise
# meettheaddams7%
# coldpursuitmovie
# judythefilm.37%
# fivefeetapartfilm
# mamovie2019.82%
# thekitchenmovie
# jokermovie8.36%
# stubermovie.42%
# gretafilm98.59%
# theaeronautsmov
# doramovie98.46%
# annabellemovie%
# stormboymovie0%
# starwars:98.04%
# gloriabellmovie
# currentwarmovie
# disneyfrozen15%
# highlifemovie0%
# missbalamovie7%
# usmovies:98.72%
# goodliarmovie4%
# 47metersdown65%
# thelegomovie67%
# avengers:99.52%
# knivesout99.64%
# spidermanmovie%
# teenspiritmov4%
# .ipynb_checkpoints
# apollo11movie
# adogsjourneymovie
# goodboysmovie5%
# Progress:97.56%

# %% [markdown]
# ## Filename to genre matrix dataframe

# %%
df = pd.DataFrame(li, columns = ['from', 'filename'] + genres).sort_values(by='filename')
df
# Out:
#                                                     from  \
# 17239  ../Posts/21bridgesmovie/2175018306402404394_86...
# 17240  ../Posts/21bridgesmovie/2177917366494984182_86...
# 17241  ../Posts/21bridgesmovie/2169038472928885102_86...
# 17242  ../Posts/21bridgesmovie/2198935854680323790_86...
# 17243  ../Posts/21bridgesmovie/2182191168477234869_86...
# ...                                                  ...
# 5575   ../Posts/zombieland/2137359683396335880_913973...
# 5576   ../Posts/zombieland/2137359683396335880_913973...
# 5577   ../Posts/zombieland/2137359683396335880_913973...
# 5578   ../Posts/zombieland/2218432031066716113_913973...
# 5579   ../Posts/zombieland/2202506093212990312_913973...
#
#                        filename  Action  Adventure  Animation  Biography  \
# 17239  21bridgesmovie_17239.jpg       1          0          0          0
# 17240  21bridgesmovie_17240.jpg       1          0          0          0
# 17241  21bridgesmovie_17241.jpg       1          0          0          0
# 17242  21bridgesmovie_17242.jpg       1          0          0          0
# 17243  21bridgesmovie_17243.jpg       1          0          0          0
# ...                         ...     ...        ...        ...        ...
# 5575        zombieland_5575.jpg       1          0          0          0
# 5576        zombieland_5576.jpg       1          0          0          0
# 5577        zombieland_5577.jpg       1          0          0          0
# 5578        zombieland_5578.jpg       1          0          0          0
# 5579        zombieland_5579.jpg       1          0          0          0
#
#        Comedy  Crime  Documentary  Drama  ...  History  Horror  Music  \
# 17239       0      1            0      1  ...        0       0      0
# 17240       0      1            0      1  ...        0       0      0
# 17241       0      1            0      1  ...        0       0      0
# 17242       0      1            0      1  ...        0       0      0
# 17243       0      1            0      1  ...        0       0      0
# ...       ...    ...          ...    ...  ...      ...     ...    ...
# 5575        1      0            0      0  ...        0       1      0
# 5576        1      0            0      0  ...        0       1      0
# 5577        1      0            0      0  ...        0       1      0
# 5578        1      0            0      0  ...        0       1      0
# 5579        1      0            0      0  ...        0       1      0
#
#        Mystery  Romance  Sci-Fi  Sport  Thriller  War  Western
# 17239        0        0       0      0         0    0        0
# 17240        0        0       0      0         0    0        0
# 17241        0        0       0      0         0    0        0
# 17242        0        0       0      0         0    0        0
# 17243        0        0       0      0         0    0        0
# ...        ...      ...     ...    ...       ...  ...      ...
# 5575         0        0       0      0         0    0        0
# 5576         0        0       0      0         0    0        0
# 5577         0        0       0      0         0    0        0
# 5578         0        0       0      0         0    0        0
# 5579         0        0       0      0         0    0        0
#
# [30339 rows x 22 columns]

# %%
df.to_csv('./filename2genreMat.csv', index = 0)

# %% [markdown]
# ## Count the number for each genre

# %%
df = pd.read_csv('./filename2genreMat.csv')

# %%
genreCount = pd.DataFrame(df.sum(axis = 0), columns = ['count'])
genreCount = genreCount.drop('filename')
genreCount = genreCount.drop('from')

# %%
genreCount = genreCount.sort_values(by = 'count', ascending = True)
genreCount
# Out:
#              count
# Western         36
# Documentary    262
# Sport          282
# War            352
# Music          416
# History        773
# Family         860
# Mystery       1631
# Biography     1967
# Crime         2419
# Thriller      2496
# Sci-Fi        2657
# Horror        2827
# Animation     3047
# Romance       3918
# Fantasy       6545
# Comedy        8807
# Drama        10290
# Action       11094
# Adventure    12910

# %% [markdown]
# # Select train and test part

# %%
# init 
total = {}
for g in genreCount.index:
    total[g] = 0
print(total)
df = pd.read_csv('./filename2genreMat.csv')
print(df.shape)

# %%
from IPython.display import display
trainingset = pd.DataFrame()
testingset = pd.DataFrame()
for g, row in genreCount.iterrows():
    print('current DF:', df.shape)
    print(g)
    
    remain = int(500 - total[g])
    
    newdf = df.loc[df[g] == 1]
    df = df.drop(newdf.index)
    print(newdf.shape)
#     display(newdf)
    
    if remain > 0:
        try:
            traindf = newdf.sample(n = remain)
        except ValueError:
            traindf = newdf
    else:
        continue
    
#     display(traindf)

    print(traindf.shape)
    trainingset = trainingset.append(traindf)
    testingset = testingset.append(newdf.drop(traindf.index))
    
    countdf = pd.DataFrame(traindf.sum(axis = 0), columns = ['count']).drop('filename')
#     display(countdf)
    
    for genre, row in countdf.iterrows():
        total[genre] += row['count']
        
    print(total)
    
    print('==================================================')

# %%
total

# %%
import matplotlib.pyplot as plt

names = list(total.keys())
values = list(total.values())

plt.figure(figsize=(20, 5))
plt.ylim(0, 2000) 
plt.bar(names, values, align='center', width=0.5)

for a,b in zip(names, values):  
    plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=10)
    
plt.show()

# %%
trainingset.to_csv('./Sample/input_df/trainMatrix.csv', index = 0)
trainingset

# %%
testingset.to_csv('./Sample/input_df/testMatrix.csv', index = 0)
testingset
